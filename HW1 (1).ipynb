# %%
name = input("What your name? ")

print ( "Hello", name )
# Out:
# What your name? Demarko
# Hello Demarko

# %%
 x = input ("1st number")
 y = input ("2nd number")
print (int(x) * int(y))
print (int(x)-int(y))
print (int(x)+int(y))
print (int(x)/int(y))
# Out:
# 1st number10
# 2nd number100
# 1000
# -90
# 110
# 0.1

# %%
Temp = input ("Enter Temperature in Degrees Fahrenheit ")

print ("Your temperature in Degree Celsius is ")
print ((int(Temp)-32)*(5/9) )
# Out:
# Enter Temperature in Fahrenheit 212
# Your temperature in Celsius is
# 100.0
