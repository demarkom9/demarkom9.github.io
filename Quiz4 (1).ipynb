# %%
words = ["data", "science", "ai"]
a = words
b = words[:]
a[0] = "big"
b[1] = "machine"
print(words)
# Out:
# ['big', 'science', 'ai']

# %%
words = ["cat", "dog", "elephant", "ant"]
result = [w for w in words if len(w) > 3]
print(result)
# Out:
# ['elephant']

# %%
parts = ["EE", "1108", "Python"]
s = "-".join(parts)
print(s)
# Out:
# EE-1108-Python

# %%
words = ["apple", "banana", "cherry"]

# %%
words = ["pear", "Apple", "banana"]
words.sort()
print(words)
# Out:
# ['Apple', 'banana', 'pear']
